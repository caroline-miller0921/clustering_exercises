# %%
# ignore warnings
import warnings
warnings.filterwarnings("ignore")

# Wrangling
import pandas as pd
import numpy as np

# Exploring
import scipy.stats as stats

# Visualizing
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# default pandas decimal number display format
pd.options.display.float_format = '{:20,.2f}'.format

import acquire
import summarize as s
import prepare
from env import username as u, password as p, host as h, url
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display

import wrangle_mall as w

# %%
df = w.get_mall_customers()
df
# Out:
#      customer_id  gender  age  annual_income  spending_score
# 0              1    Male   19             15              39
# 1              2    Male   21             15              81
# 2              3  Female   20             16               6
# 3              4  Female   23             16              77
# 4              5  Female   31             17              40
# ..           ...     ...  ...            ...             ...
# 195          196  Female   35            120              79
# 196          197  Female   45            126              28
# 197          198    Male   32            126              74
# 198          199    Male   32            137              18
# 199          200    Male   30            137              83
#
# [200 rows x 5 columns]

# %%
s.summarize(df)
# Out:
#                     SUMMARY REPORT
# ...
#
#
# Dataframe head:
#    customer_id  gender  age  annual_income  spending_score
# 0            1    Male   19             15              39
# 1            2    Male   21             15              81
# 2            3  Female   20             16               6
# ...
#
#
# Dataframe info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customer_id     200 non-null    int64
#  1   gender          200 non-null    object
#  2   age             200 non-null    int64
#  3   annual_income   200 non-null    int64
#  4   spending_score  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB
# Empty DataFrame
# Columns: []
# Index: []
# ...
#
#
# Dataframe Description:
#                               count                 mean                  std  \
# ...

# %%
df.columns
# Out:
# Index(['customer_id', 'gender', 'age', 'annual_income', 'spending_score'], dtype='object')

# %%
train, validate, test = w.wrangle_mall()
# Out:
#                     SUMMARY REPORT
# ...
#
#
# Dataframe head:
#    customer_id  gender  age  annual_income  spending_score
# 0            1    Male   19             15              39
# 1            2    Male   21             15              81
# 2            3  Female   20             16               6
# ...
#
#
# Dataframe info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customer_id     200 non-null    int64
#  1   gender          200 non-null    object
#  2   age             200 non-null    int64
#  3   annual_income   200 non-null    int64
#  4   spending_score  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB
# Empty DataFrame
# Columns: []
# Index: []
# ...
#
#
# Dataframe Description:
#                               count                 mean                  std  \
# ...

# %%
train_scaled, validate_scaled, test_scaled = w.scale_data(train, validate, test, columns_to_scale=['age', 'annual_income', 'spending_score'])

# %%
train_scaled.head()
# Out:
#                     age        annual_income       spending_score  gender_Male
# 26                 0.52                 0.12                 0.32            0
# 23                 0.25                 0.10                 0.73            1
# 39                 0.04                 0.21                 0.76            0
# 37                 0.23                 0.18                 0.73            0
# 56                 0.63                 0.28                 0.50            0
